# %% [markdown]
# # Introduction
#
# This script performs RSA on FashionMNIST models. The loop in which the models are trained is commented out as the trained models are provided on github. They need to be saved in the directory specified here. Ensure that the notebook is able to save files in the working directory.

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)
working_directory       = 'path here/' 
fashionmnist_saves_conv = 'directory name here'  
fashionmnist_saves_mlp  = 'directory name here'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Model training and computing Performances

# %% [markdown]
# Data is split into 1) train 2) test and 3) valid. Models are trained on train, accuracies estimated on test. Valid is used to perform RSA on.

# %%
import torchvision
import torch
import numpy as np
import scipy.stats
import sklearn.manifold
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn
import pandas as pd
import sklearn
import os
import pickle
import time
from scipy.spatial import distance
from sklearn.metrics.pairwise import manhattan_distances
import torch.nn as nn
from copy import deepcopy


transforms = torchvision.transforms.Compose([
                           torchvision.transforms.ToTensor(),
                       ])

FashionMNIST_train = torchvision.datasets.FashionMNIST(root='./data',train=True, transform=transforms, download=True)
FashionMNIST_train, FashionMNIST_valid = sklearn.model_selection.train_test_split(FashionMNIST_train, test_size=0.1, random_state=1)
FashionMNIST_test = torchvision.datasets.FashionMNIST(root='./data',train=False, transform= transforms, download=True)

dataloader_train = torch.utils.data.DataLoader(FashionMNIST_train, batch_size = 200, shuffle = True)
dataloader_test = torch.utils.data.DataLoader(FashionMNIST_test, batch_size = 10000, shuffle = False)

# %% [markdown]
# ## Model class definitions
# Model classes are defined with hidden layer sizes as variables.

# %%
class feedforward(torch.nn.Module):
    
    def __init__(self, D_in, Hidden, Hidden2, Hidden3, D_out):
  
        super(feedforward, self).__init__()
        self.linear1 = torch.nn.Linear(D_in, Hidden)
        self.linear2 = torch.nn.Linear(Hidden, Hidden2)
        self.linear3 = torch.nn.Linear(Hidden2, Hidden3)
        self.linear4 = torch.nn.Linear(Hidden3, D_out)
        self.sigmoid = torch.nn.Sigmoid()


    def forward(self, x):
      
        l1_activ = self.sigmoid(self.linear1(x))
        l2_activ = self.sigmoid(self.linear2(l1_activ))
        l3_activ = self.sigmoid(self.linear3(l2_activ))
        y_pred =   self.linear4(l3_activ)
        
        return y_pred, l3_activ, l2_activ, l1_activ




class ConvNet(torch.nn.Module):
    
    def __init__(self, h, j):
        
        super(ConvNet, self).__init__()
        
        self.layer1 = nn.Sequential(nn.Conv2d(1, h * 2, kernel_size=5, stride=1, padding=2),
                                    nn.MaxPool2d(kernel_size=2, stride=2),
                                    nn.ReLU(),
                                    nn.BatchNorm2d(h * 2))
     
        self.fc1 = nn.Sequential(nn.Linear(14 * 14 * h * 2, j * 16),
                                 nn.ReLU(),
                                 nn.BatchNorm1d(j * 16),
                                 nn.Dropout(p = 0.5))
       
        self.fc2 = nn.Sequential(nn.Linear(j * 16, j * 8),
                                 nn.Sigmoid(),
                                 nn.BatchNorm1d(j * 8),
                                 nn.Dropout(p = 0.5))                           
      
        self.fc3 = nn.Linear(j*8, 10)

        
    def forward(self, x):
        
        conv1 = self.layer1(x)
        reshaped = conv1.reshape(conv1.size(0), -1)
        fc1 = self.fc1(reshaped)
        fc2 = self.fc2(fc1)                             
        out = self.fc3(fc2)
        return [out, fc2, fc1, reshaped, conv1]
            
criterion = torch.nn.CrossEntropyLoss()

# %% [markdown]
# ## Training CNNs in a loop
# This loop is used to generate CNNs. Every model has a different number of filters/units in each hidden layer. Every model is saved in a seperate file in the same folder. Accuracy is reported but not saved. It is computed again when loading the models, to ensure there is no bug.

# %%
'''
model_index = 0

for h in range(2,15):
    for j in range(2,16):
          
        model = ConvNet(h, j).cuda()
        criterion = torch.nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters(), lr= 0.01)


        for epoch in range(15):
            for (inputs, labels) in (dataloader_train):
    
                model.train()
                inputs, labels = inputs.cuda(), labels.cuda()
                outputs = model(inputs)[0]
                loss = criterion(outputs, labels)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        with torch.no_grad():
            for (inputs, labels) in (dataloader_test):
            
                model.eval()
                inputs, labels = inputs.cuda(), labels.cuda()
                out = model(inputs)[0]
                total = labels.size(0)
                correct = ((torch.max(out,1)[1]) == labels).sum()
                acc =   correct.float() / total
                print(acc)
        
            state = {'layers': [h,j],
                     'epoch': epoch, 'state_dict': model.state_dict()}
            try:
              
                 os.makedirs(f'{working_directory}/{fashionmnist_saves_conv/')
                
            except FileExistsError:
              
                pass
              
            torch.save(state, f'{working_directory}/{fashionmnist_saves_conv/{model_index}.tar')
            model_index += 1
            
'''
# Out:
# "\nmodel_index = 0\n\nfor h in range(2,15):\n    for j in range(2,16):\n          \n        model = ConvNet(h, j).cuda()\n        criterion = torch.nn.CrossEntropyLoss()\n        optimizer = torch.optim.Adam(model.parameters(), lr= 0.01)\n\n\n        for epoch in range(15):\n            for (inputs, labels) in (dataloader_train):\n    \n                model.train()\n                inputs, labels = inputs.cuda(), labels.cuda()\n                outputs = model(inputs)[0]\n                loss = criterion(outputs, labels)\n                optimizer.zero_grad()\n                loss.backward()\n                optimizer.step()\n                \n        with torch.no_grad():\n            for (inputs, labels) in (dataloader_test):\n            \n                model.eval()\n                inputs, labels = inputs.cuda(), labels.cuda()\n                out = model(inputs)[0]\n                total = labels.size(0)\n                correct = ((torch.max(out,1)[1]) == labels).sum()\n                acc =   correct.float() / total\n                print(acc)\n        \n            state = {'layers': [h,j],\n                     'epoch': epoch, 'state_dict': model.state_dict()}\n            try:\n              \n                 os.makedirs(f'{working_directory}/{fashionmnist_saves_conv/')\n                \n            except FileExistsError:\n              \n                pass\n              \n            torch.save(state, f'{working_directory}/{fashionmnist_saves_conv/{model_index}.tar')\n            model_index += 1\n            \n"

# %% [markdown]
# ## Compute CNN accuracies
# Loads the CNNs and computes accuracies, saves accuracies as a list.

# %%
acc_list = []
conv_saves = f'{working_directory}/{fashionmnist_saves_conv}/'
for save in os.listdir(conv_saves):
    
    model_dict = torch.load(f'{working_directory}/{fashionmnist_saves_conv}/{save}')
    layers = model_dict['layers']
    model = ConvNet(*layers).cuda()
    model.load_state_dict(model_dict['state_dict'])

  
    with torch.no_grad():
         for i, (inputs, labels) in enumerate(dataloader_test):
        
            inputs, labels = (inputs, labels)
            inputs, labels = inputs.cuda(), labels.long().cuda()
            out = model(inputs)[0]
            total = labels.size(0)
            correct = ((torch.max(out,1)[1]) == labels).sum()
            acc =   correct.float() / total
            
    print(f'Test accuracy of the network: {acc}')
    acc_list.append([acc.cpu().numpy(),save])
    
with open(f'{working_directory}/accuracy_list_fashionmnist_cnn.pkl', 'wb') as fp:
   
    pickle.dump(acc_list, fp)
# Out:
# Test accuracy of the network: 0.8107999563217163
# Test accuracy of the network: 0.8517000079154968
# Test accuracy of the network: 0.8671000003814697
# Test accuracy of the network: 0.8725000023841858
# Test accuracy of the network: 0.8823999762535095
# Test accuracy of the network: 0.8789999485015869
# Test accuracy of the network: 0.883899986743927
# Test accuracy of the network: 0.8834999799728394
# Test accuracy of the network: 0.8795999884605408
# Test accuracy of the network: 0.8817999958992004
# Test accuracy of the network: 0.8860999941825867
# Test accuracy of the network: 0.887999951839447
# Test accuracy of the network: 0.8880999684333801
# Test accuracy of the network: 0.8818999528884888
# Test accuracy of the network: 0.8305000066757202
# Test accuracy of the network: 0.8637999892234802
# Test accuracy of the network: 0.8736000061035156
# Test accuracy of the network: 0.8860999941825867
# Test accuracy of the network: 0.8831999897956848
# Test accuracy of the network: 0.8849999904632568
# Test accuracy of the network: 0.8840000033378601
# Test accuracy of the network: 0.8845999836921692
# Test accuracy of the network: 0.8898999691009521
# Test accuracy of the network: 0.8906999826431274
# Test accuracy of the network: 0.8871999979019165
# Test accuracy of the network: 0.8902999758720398
# Test accuracy of the network: 0.8896999955177307
# Test accuracy of the network: 0.8922999501228333
# Test accuracy of the network: 0.824400007724762
# Test accuracy of the network: 0.8720999956130981
# Test accuracy of the network: 0.8827999830245972
# Test accuracy of the network: 0.8845999836921692
# Test accuracy of the network: 0.8876999616622925
# Test accuracy of the network: 0.8905999660491943
# Test accuracy of the network: 0.8876000046730042
# Test accuracy of the network: 0.8939999938011169
# Test accuracy of the network: 0.8894000053405762
# Test accuracy of the network: 0.8955000042915344
# Test accuracy of the network: 0.8902999758720398
# Test accuracy of the network: 0.8938999772071838
# Test accuracy of the network: 0.8920999765396118
# Test accuracy of the network: 0.8903999924659729
# Test accuracy of the network: 0.8317999839782715
# Test accuracy of the network: 0.8702999949455261
# Test accuracy of the network: 0.8819999694824219
# Test accuracy of the network: 0.8901000022888184
# Test accuracy of the network: 0.8887999653816223
# Test accuracy of the network: 0.8916999697685242
# Test accuracy of the network: 0.8923999667167664
# Test accuracy of the network: 0.8894999623298645
# Test accuracy of the network: 0.8922999501228333
# Test accuracy of the network: 0.8892999887466431
# Test accuracy of the network: 0.8981999754905701
# Test accuracy of the network: 0.8930000066757202
# Test accuracy of the network: 0.8985999822616577
# Test accuracy of the network: 0.8949999809265137
# Test accuracy of the network: 0.8278999924659729
# Test accuracy of the network: 0.8748999834060669
# Test accuracy of the network: 0.8837999701499939
# Test accuracy of the network: 0.8908999562263489
# Test accuracy of the network: 0.8894000053405762
# Test accuracy of the network: 0.8913999795913696
# Test accuracy of the network: 0.8953999876976013
# Test accuracy of the network: 0.897599995136261
# Test accuracy of the network: 0.8970999717712402
# Test accuracy of the network: 0.8923999667167664
# Test accuracy of the network: 0.8949999809265137
# Test accuracy of the network: 0.8930000066757202
# Test accuracy of the network: 0.8955999612808228
# Test accuracy of the network: 0.8873999714851379
# Test accuracy of the network: 0.8353999853134155
# Test accuracy of the network: 0.8761000037193298
# Test accuracy of the network: 0.8855999708175659
# Test accuracy of the network: 0.88919997215271
# Test accuracy of the network: 0.8952999711036682
# Test accuracy of the network: 0.8991999626159668
# Test accuracy of the network: 0.8937999606132507
# Test accuracy of the network: 0.8991999626159668
# Test accuracy of the network: 0.8978999853134155
# Test accuracy of the network: 0.8996999859809875
# Test accuracy of the network: 0.8985999822616577
# Test accuracy of the network: 0.8949999809265137
# Test accuracy of the network: 0.8940999507904053
# Test accuracy of the network: 0.8988999724388123
# Test accuracy of the network: 0.8446999788284302
# Test accuracy of the network: 0.8746999502182007
# Test accuracy of the network: 0.8812999725341797
# Test accuracy of the network: 0.8871999979019165
# Test accuracy of the network: 0.8933999538421631
# Test accuracy of the network: 0.8962000012397766
# Test accuracy of the network: 0.8947999477386475
# Test accuracy of the network: 0.8996999859809875
# Test accuracy of the network: 0.8991999626159668
# Test accuracy of the network: 0.8992999792098999
# Test accuracy of the network: 0.8976999521255493
# Test accuracy of the network: 0.8977999687194824
# Test accuracy of the network: 0.9019999504089355
# Test accuracy of the network: 0.9031999707221985
# Test accuracy of the network: 0.8378999829292297
# Test accuracy of the network: 0.8737999796867371
# Test accuracy of the network: 0.8869999647140503
# Test accuracy of the network: 0.8885999917984009
# Test accuracy of the network: 0.8937999606132507
# Test accuracy of the network: 0.8876999616622925
# Test accuracy of the network: 0.8991999626159668
# Test accuracy of the network: 0.895799994468689
# Test accuracy of the network: 0.8958999514579773
# Test accuracy of the network: 0.8995999693870544
# Test accuracy of the network: 0.8981999754905701
# Test accuracy of the network: 0.896399974822998
# Test accuracy of the network: 0.9023999571800232
# Test accuracy of the network: 0.8999999761581421
# Test accuracy of the network: 0.8380999565124512
# Test accuracy of the network: 0.877299964427948
# Test accuracy of the network: 0.8912999629974365
# Test accuracy of the network: 0.8939999938011169
# Test accuracy of the network: 0.8955000042915344
# Test accuracy of the network: 0.9013999700546265
# Test accuracy of the network: 0.8977999687194824
# Test accuracy of the network: 0.899899959564209
# Test accuracy of the network: 0.8971999883651733
# Test accuracy of the network: 0.899899959564209
# Test accuracy of the network: 0.9000999927520752
# Test accuracy of the network: 0.9000999927520752
# Test accuracy of the network: 0.8989999890327454
# Test accuracy of the network: 0.8980000019073486
# Test accuracy of the network: 0.8351999521255493
# Test accuracy of the network: 0.8779000043869019
# Test accuracy of the network: 0.8899999856948853
# Test accuracy of the network: 0.8947999477386475
# Test accuracy of the network: 0.8950999975204468
# Test accuracy of the network: 0.9003999829292297
# Test accuracy of the network: 0.8994999527931213
# Test accuracy of the network: 0.8980000019073486
# Test accuracy of the network: 0.899899959564209
# Test accuracy of the network: 0.8962999582290649
# Test accuracy of the network: 0.8958999514579773
# Test accuracy of the network: 0.9023000001907349
# Test accuracy of the network: 0.8851000070571899
# Test accuracy of the network: 0.8969999551773071
# Test accuracy of the network: 0.8393999934196472

# %% [markdown]
# ## Train MLPs in a loop
# Train the MLPs in a loop (similar to CNNs). Save a a dictionary including all necessary information to reload them.

# %%
'''
model_index = 0
for i in range(8):
    for j in range(8):
        for h in range(8):
            
            layers = [28*28, i*2 +j*2 + h*2 +3, j*2 + h*2 +3, h*2 +3 ,10]
            model   = feedforward(*layers).cuda()
            optimizer = torch.optim.Adam(model.parameters(), lr= 0.001)
            for epoch in range(15):
                for h, (inputs, labels) in enumerate(dataloader_train):
        
                    inputs, labels = (inputs, labels)
                    inputs, labels = torch.autograd.Variable(inputs).view((-1, 28*28)).float().cuda(), torch.autograd.Variable(labels).long().cuda()
                    out = model(inputs)[0]
                    loss = criterion(out, labels)
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
               
            state = {'layers': layers,
                     'epoch': epoch,'state_dict': model.state_dict(), 'optimizer': optimizer.state_dict()}
            try:
              
                os.makedirs(f'{working_directory}/{fashionmnist_saves_mlp}')
            except FileExistsError:
              
                pass
            
            torch.save(state, f'{working_directory}/{fashionmnist_saves_mlp}/{model_index}.tar')
            print(model_index)
            model_index += 1
            
'''
# Out:
# "\nmodel_index = 0\nfor i in range(8):\n    for j in range(8):\n        for h in range(8):\n            \n            layers = [28*28, i*2 +j*2 + h*2 +3, j*2 + h*2 +3, h*2 +3 ,10]\n            model   = feedforward(*layers).cuda()\n            optimizer = torch.optim.Adam(model.parameters(), lr= 0.001)\n            for epoch in range(15):\n                for h, (inputs, labels) in enumerate(dataloader_train):\n        \n                    inputs, labels = (inputs, labels)\n                    inputs, labels = torch.autograd.Variable(inputs).view((-1, 28*28)).float().cuda(), torch.autograd.Variable(labels).long().cuda()\n                    out = model(inputs)[0]\n                    loss = criterion(out, labels)\n                    optimizer.zero_grad()\n                    loss.backward()\n                    optimizer.step()\n               \n            state = {'layers': layers,\n                     'epoch': epoch,'state_dict': model.state_dict(), 'optimizer': optimizer.state_dict()}\n            try:\n              \n                os.makedirs(f'{working_directory}/{fashionmnist_saves_mlp}')\n            except FileExistsError:\n              \n                pass\n            \n            torch.save(state, f'{working_directory}/{fashionmnist_saves_mlp}/{model_index}.tar')\n            print(model_index)\n            model_index += 1\n            \n"

# %% [markdown]
# ## Compute MLP accuracies
# Loads the saved MLP models and computes accuracies. Saves accuracies in a list.

# %%
mlp_saves = f'{working_directory}/{fashionmnist_saves_mlp}'

acc_list = []
for save in os.listdir(mlp_saves):
    
    model_dict = torch.load(f'{working_directory}/{fashionmnist_saves_mlp}/{save}')
    layers = model_dict['layers']
    model = feedforward(*layers).cuda()
    model.eval()
    model.load_state_dict(model_dict['state_dict'])

  
    with torch.no_grad():
         for i, (inputs, labels) in enumerate(dataloader_test):    
        
            inputs, labels = (inputs, labels)
            inputs, labels = torch.autograd.Variable(inputs).view((-1, 28*28)).float().cuda(), torch.autograd.Variable(labels).long().cuda()
            out = model(inputs)[0]
            total = labels.size(0)
            correct = ((torch.max(out,1)[1]) == labels).sum()
            acc =   correct.float() / total
            
    print(f'Test accuracy of the network: {acc}')
    acc_list.append([acc.cpu().numpy(),save])
    
with open(f'{working_directory}/accuracy_list_fashionmnist_mlp.pkl', 'wb') as fp:
    
    pickle.dump(acc_list, fp)
# Out:
# Test accuracy of the network: 0.5507000088691711
# Test accuracy of the network: 0.675599992275238
# Test accuracy of the network: 0.8018999695777893
# Test accuracy of the network: 0.7699999809265137
# Test accuracy of the network: 0.6991999745368958
# Test accuracy of the network: 0.5741999745368958
# Test accuracy of the network: 0.6505999565124512
# Test accuracy of the network: 0.7443000078201294
# Test accuracy of the network: 0.7166999578475952
# Test accuracy of the network: 0.4892999827861786
# Test accuracy of the network: 0.7339000105857849
# Test accuracy of the network: 0.5722999572753906
# Test accuracy of the network: 0.4869999885559082
# Test accuracy of the network: 0.8082000017166138
# Test accuracy of the network: 0.7788999676704407
# Test accuracy of the network: 0.8014000058174133
# Test accuracy of the network: 0.6636999845504761
# Test accuracy of the network: 0.7128999829292297
# Test accuracy of the network: 0.6534000039100647
# Test accuracy of the network: 0.8265999555587769
# Test accuracy of the network: 0.804099977016449
# Test accuracy of the network: 0.6995999813079834
# Test accuracy of the network: 0.7462999820709229
# Test accuracy of the network: 0.838699996471405
# Test accuracy of the network: 0.7870999574661255
# Test accuracy of the network: 0.6581999659538269
# Test accuracy of the network: 0.8393999934196472
# Test accuracy of the network: 0.7985000014305115
# Test accuracy of the network: 0.821899950504303
# Test accuracy of the network: 0.8438999652862549
# Test accuracy of the network: 0.6013000011444092
# Test accuracy of the network: 0.8410999774932861
# Test accuracy of the network: 0.786799967288971
# Test accuracy of the network: 0.5271999835968018
# Test accuracy of the network: 0.8508999943733215
# Test accuracy of the network: 0.802899956703186
# Test accuracy of the network: 0.7569999694824219
# Test accuracy of the network: 0.8440999984741211
# Test accuracy of the network: 0.8460999727249146
# Test accuracy of the network: 0.820099949836731
# Test accuracy of the network: 0.8057999610900879
# Test accuracy of the network: 0.8509999513626099
# Test accuracy of the network: 0.8522999882698059
# Test accuracy of the network: 0.8147000074386597
# Test accuracy of the network: 0.8226000070571899
# Test accuracy of the network: 0.8190999627113342
# Test accuracy of the network: 0.8334999680519104
# Test accuracy of the network: 0.8489999771118164
# Test accuracy of the network: 0.8230999708175659
# Test accuracy of the network: 0.8407999873161316
# Test accuracy of the network: 0.8466999530792236
# Test accuracy of the network: 0.8399999737739563
# Test accuracy of the network: 0.7710999846458435
# Test accuracy of the network: 0.8303999900817871
# Test accuracy of the network: 0.7752999663352966
# Test accuracy of the network: 0.7339000105857849
# Test accuracy of the network: 0.5385000109672546
# Test accuracy of the network: 0.7874000072479248
# Test accuracy of the network: 0.7658999562263489
# Test accuracy of the network: 0.848800003528595
# Test accuracy of the network: 0.8513000011444092
# Test accuracy of the network: 0.8201999664306641
# Test accuracy of the network: 0.8371999859809875
# Test accuracy of the network: 0.8537999987602234
# Test accuracy of the network: 0.6592999696731567
# Test accuracy of the network: 0.6837999820709229
# Test accuracy of the network: 0.8262999653816223
# Test accuracy of the network: 0.7568999528884888
# Test accuracy of the network: 0.8062999844551086
# Test accuracy of the network: 0.6751999855041504
# Test accuracy of the network: 0.7870999574661255
# Test accuracy of the network: 0.7889999747276306
# Test accuracy of the network: 0.7760999798774719
# Test accuracy of the network: 0.7964999675750732
# Test accuracy of the network: 0.8294000029563904
# Test accuracy of the network: 0.8017999529838562
# Test accuracy of the network: 0.6462000012397766
# Test accuracy of the network: 0.7206999659538269
# Test accuracy of the network: 0.7283999919891357
# Test accuracy of the network: 0.6776999831199646
# Test accuracy of the network: 0.8064000010490417
# Test accuracy of the network: 0.6383999586105347
# Test accuracy of the network: 0.6380999684333801
# Test accuracy of the network: 0.8283999562263489
# Test accuracy of the network: 0.7426999807357788
# Test accuracy of the network: 0.49959999322891235
# Test accuracy of the network: 0.8144999742507935
# Test accuracy of the network: 0.8468999862670898
# Test accuracy of the network: 0.7529000043869019
# Test accuracy of the network: 0.8345999717712402
# Test accuracy of the network: 0.8112999796867371
# Test accuracy of the network: 0.7906999588012695
# Test accuracy of the network: 0.8216999769210815
# Test accuracy of the network: 0.6553999781608582
# Test accuracy of the network: 0.7382000088691711
# Test accuracy of the network: 0.8542999625205994
# Test accuracy of the network: 0.5734999775886536
# Test accuracy of the network: 0.8479999899864197
# Test accuracy of the network: 0.8082000017166138
# Test accuracy of the network: 0.7724999785423279
# Test accuracy of the network: 0.6331999897956848
# Test accuracy of the network: 0.8319999575614929
# Test accuracy of the network: 0.8377999663352966
# Test accuracy of the network: 0.8580999970436096
# Test accuracy of the network: 0.8447999954223633
# Test accuracy of the network: 0.7526999711990356
# Test accuracy of the network: 0.8048999905586243
# Test accuracy of the network: 0.8029999732971191
# Test accuracy of the network: 0.8535999655723572
# Test accuracy of the network: 0.8563999533653259
# Test accuracy of the network: 0.8535999655723572
# Test accuracy of the network: 0.8589999675750732
# Test accuracy of the network: 0.7534999847412109
# Test accuracy of the network: 0.722599983215332
# Test accuracy of the network: 0.7691999673843384
# Test accuracy of the network: 0.8175999522209167
# Test accuracy of the network: 0.760699987411499
# Test accuracy of the network: 0.8204999566078186
# Test accuracy of the network: 0.8342999815940857
# Test accuracy of the network: 0.8544999957084656
# Test accuracy of the network: 0.7124999761581421
# Test accuracy of the network: 0.8613999485969543
# Test accuracy of the network: 0.8489999771118164
# Test accuracy of the network: 0.6207999587059021
# Test accuracy of the network: 0.8211999535560608
# Test accuracy of the network: 0.858299970626831
# Test accuracy of the network: 0.8432999849319458
# Test accuracy of the network: 0.8458999991416931
# Test accuracy of the network: 0.6926999688148499
# Test accuracy of the network: 0.6965999603271484
# Test accuracy of the network: 0.7626000046730042
# Test accuracy of the network: 0.7937999963760376
# Test accuracy of the network: 0.7581999897956848
# Test accuracy of the network: 0.8459999561309814
# Test accuracy of the network: 0.7342000007629395
# Test accuracy of the network: 0.7732999920845032
# Test accuracy of the network: 0.4878999888896942
# Test accuracy of the network: 0.773099958896637
# Test accuracy of the network: 0.6017999649047852
# Test accuracy of the network: 0.7990999817848206
# Test accuracy of the network: 0.8316999673843384
# Test accuracy of the network: 0.8112999796867371
# Test accuracy of the network: 0.6548999547958374
# Test accuracy of the network: 0.8459999561309814
# Test accuracy of the network: 0.7878999710083008
# Test accuracy of the network: 0.7107999920845032
# Test accuracy of the network: 0.6326000094413757
# Test accuracy of the network: 0.7109000086784363
# Test accuracy of the network: 0.8447999954223633
# Test accuracy of the network: 0.7479999661445618
# Test accuracy of the network: 0.8464999794960022
# Test accuracy of the network: 0.8509999513626099
# Test accuracy of the network: 0.7411999702453613
# Test accuracy of the network: 0.7164999842643738
# Test accuracy of the network: 0.799299955368042
# Test accuracy of the network: 0.856499969959259
# Test accuracy of the network: 0.8465999960899353
# Test accuracy of the network: 0.8519999980926514
# Test accuracy of the network: 0.8579999804496765
# Test accuracy of the network: 0.8556999564170837
# Test accuracy of the network: 0.7285999655723572
# Test accuracy of the network: 0.7531999945640564
# Test accuracy of the network: 0.819599986076355
# Test accuracy of the network: 0.7723000049591064
# Test accuracy of the network: 0.7434999942779541
# Test accuracy of the network: 0.8524999618530273
# Test accuracy of the network: 0.8448999524116516
# Test accuracy of the network: 0.793999969959259
# Test accuracy of the network: 0.5388999581336975
# Test accuracy of the network: 0.8374999761581421
# Test accuracy of the network: 0.8267999887466431
# Test accuracy of the network: 0.7286999821662903
# Test accuracy of the network: 0.837399959564209
# Test accuracy of the network: 0.8460999727249146
# Test accuracy of the network: 0.6771000027656555
# Test accuracy of the network: 0.851099967956543
# Test accuracy of the network: 0.7547000050544739
# Test accuracy of the network: 0.8089999556541443
# Test accuracy of the network: 0.6682999730110168
# Test accuracy of the network: 0.8549000024795532
# Test accuracy of the network: 0.8478999733924866
# Test accuracy of the network: 0.7723999619483948
# Test accuracy of the network: 0.8227999806404114
# Test accuracy of the network: 0.85999995470047
# Test accuracy of the network: 0.762999951839447
# Test accuracy of the network: 0.8610000014305115
# Test accuracy of the network: 0.7447999715805054
# Test accuracy of the network: 0.8328999876976013
# Test accuracy of the network: 0.8651999831199646
# Test accuracy of the network: 0.8287000060081482
# Test accuracy of the network: 0.8406999707221985
# Test accuracy of the network: 0.8542999625205994
# Test accuracy of the network: 0.7960999608039856
# Test accuracy of the network: 0.531499981880188
# Test accuracy of the network: 0.7670999765396118
# Test accuracy of the network: 0.7782999873161316
# Test accuracy of the network: 0.8113999962806702
# Test accuracy of the network: 0.8411999940872192
# Test accuracy of the network: 0.8330999612808228
# Test accuracy of the network: 0.8486999869346619
# Test accuracy of the network: 0.4000999927520752
# Test accuracy of the network: 0.8229999542236328
# Test accuracy of the network: 0.7954999804496765
# Test accuracy of the network: 0.8215999603271484
# Test accuracy of the network: 0.8561999797821045
# Test accuracy of the network: 0.7220999598503113
# Test accuracy of the network: 0.847000002861023
# Test accuracy of the network: 0.8496999740600586
# Test accuracy of the network: 0.7191999554634094
# Test accuracy of the network: 0.693399965763092
# Test accuracy of the network: 0.6222999691963196
# Test accuracy of the network: 0.6340999603271484
# Test accuracy of the network: 0.7319999933242798
# Test accuracy of the network: 0.8039000034332275
# Test accuracy of the network: 0.8611999750137329
# Test accuracy of the network: 0.8603999614715576
# Test accuracy of the network: 0.7590000033378601
# Test accuracy of the network: 0.7125999927520752
# Test accuracy of the network: 0.553600013256073
# Test accuracy of the network: 0.8075000047683716
# Test accuracy of the network: 0.8188999891281128
# Test accuracy of the network: 0.589199960231781
# Test accuracy of the network: 0.8499000072479248
# Test accuracy of the network: 0.850600004196167
# Test accuracy of the network: 0.5940999984741211
# Test accuracy of the network: 0.7106999754905701
# Test accuracy of the network: 0.7639999985694885
# Test accuracy of the network: 0.7523999810218811
# Test accuracy of the network: 0.8587999939918518
# Test accuracy of the network: 0.8280999660491943
# Test accuracy of the network: 0.858199954032898
# Test accuracy of the network: 0.838699996471405
# Test accuracy of the network: 0.7049999833106995
# Test accuracy of the network: 0.7622999548912048
# Test accuracy of the network: 0.8551999926567078
# Test accuracy of the network: 0.7497000098228455
# Test accuracy of the network: 0.8578999638557434
# Test accuracy of the network: 0.8597999811172485
# Test accuracy of the network: 0.8392999768257141
# Test accuracy of the network: 0.8333999514579773
# Test accuracy of the network: 0.7240999937057495
# Test accuracy of the network: 0.7368999719619751
# Test accuracy of the network: 0.6994999647140503
# Test accuracy of the network: 0.852400004863739
# Test accuracy of the network: 0.820099949836731
# Test accuracy of the network: 0.8578999638557434
# Test accuracy of the network: 0.8118000030517578
# Test accuracy of the network: 0.8452000021934509
# Test accuracy of the network: 0.7476999759674072
# Test accuracy of the network: 0.7335999608039856
# Test accuracy of the network: 0.8047999739646912
# Test accuracy of the network: 0.8711999654769897
# Test accuracy of the network: 0.8555999994277954
# Test accuracy of the network: 0.8298999667167664
# Test accuracy of the network: 0.8583999872207642
# Test accuracy of the network: 0.849399983882904
# Test accuracy of the network: 0.5210999846458435
# Test accuracy of the network: 0.7389000058174133
# Test accuracy of the network: 0.8070999979972839
# Test accuracy of the network: 0.51910001039505
# Test accuracy of the network: 0.852899968624115
# Test accuracy of the network: 0.7813999652862549
# Test accuracy of the network: 0.8518999814987183
# Test accuracy of the network: 0.8557999730110168
# Test accuracy of the network: 0.7998999953269958
# Test accuracy of the network: 0.8223999738693237
# Test accuracy of the network: 0.7949999570846558
# Test accuracy of the network: 0.7351999878883362
# Test accuracy of the network: 0.8526999950408936
# Test accuracy of the network: 0.8499000072479248
# Test accuracy of the network: 0.8583999872207642
# Test accuracy of the network: 0.6651999950408936
# Test accuracy of the network: 0.676800012588501
# Test accuracy of the network: 0.8513999581336975
# Test accuracy of the network: 0.8181999921798706
# Test accuracy of the network: 0.724399983882904
# Test accuracy of the network: 0.8450999855995178
# Test accuracy of the network: 0.8226000070571899
# Test accuracy of the network: 0.8501999974250793
# Test accuracy of the network: 0.8552999496459961
# Test accuracy of the network: 0.8202999830245972
# Test accuracy of the network: 0.7953999638557434
# Test accuracy of the network: 0.8158999681472778
# Test accuracy of the network: 0.861799955368042
# Test accuracy of the network: 0.6176999807357788
# Test accuracy of the network: 0.8586999773979187
# Test accuracy of the network: 0.8353999853134155
# Test accuracy of the network: 0.8604999780654907
# Test accuracy of the network: 0.7502999901771545
# Test accuracy of the network: 0.8545999526977539
# Test accuracy of the network: 0.6825999617576599
# Test accuracy of the network: 0.835099995136261
# Test accuracy of the network: 0.8639000058174133
# Test accuracy of the network: 0.8556999564170837
# Test accuracy of the network: 0.8623999953269958
# Test accuracy of the network: 0.8565999865531921
# Test accuracy of the network: 0.7461999654769897
# Test accuracy of the network: 0.7963999509811401
# Test accuracy of the network: 0.6370999813079834
# Test accuracy of the network: 0.8156999945640564
# Test accuracy of the network: 0.7723999619483948
# Test accuracy of the network: 0.8648999929428101
# Test accuracy of the network: 0.8639999628067017
# Test accuracy of the network: 0.8560999631881714
# Test accuracy of the network: 0.7375999689102173
# Test accuracy of the network: 0.8291999697685242
# Test accuracy of the network: 0.6250999569892883
# Test accuracy of the network: 0.8592000007629395
# Test accuracy of the network: 0.8596999645233154
# Test accuracy of the network: 0.8499999642372131
# Test accuracy of the network: 0.854200005531311
# Test accuracy of the network: 0.769599974155426
# Test accuracy of the network: 0.818399965763092
# Test accuracy of the network: 0.7684999704360962
# Test accuracy of the network: 0.8447999954223633
# Test accuracy of the network: 0.8240000009536743
# Test accuracy of the network: 0.8623999953269958
# Test accuracy of the network: 0.8613999485969543
# Test accuracy of the network: 0.8606999516487122
# Test accuracy of the network: 0.8596000075340271
# Test accuracy of the network: 0.7720999717712402
# Test accuracy of the network: 0.6064000129699707
# Test accuracy of the network: 0.8244999647140503
# Test accuracy of the network: 0.8514999747276306
# Test accuracy of the network: 0.8601999878883362
# Test accuracy of the network: 0.8578999638557434
# Test accuracy of the network: 0.848800003528595
# Test accuracy of the network: 0.8478999733924866
# Test accuracy of the network: 0.8145999908447266
# Test accuracy of the network: 0.6782000064849854
# Test accuracy of the network: 0.5927000045776367
# Test accuracy of the network: 0.8351999521255493
# Test accuracy of the network: 0.6161999702453613
# Test accuracy of the network: 0.6782000064849854
# Test accuracy of the network: 0.8100000023841858
# Test accuracy of the network: 0.7999999523162842
# Test accuracy of the network: 0.7134000062942505
# Test accuracy of the network: 0.8206999897956848
# Test accuracy of the network: 0.694599986076355
# Test accuracy of the network: 0.8345999717712402
# Test accuracy of the network: 0.8241999745368958
# Test accuracy of the network: 0.8567000031471252
# Test accuracy of the network: 0.854200005531311
# Test accuracy of the network: 0.8531999588012695
# Test accuracy of the network: 0.6811000108718872
# Test accuracy of the network: 0.7989999651908875
# Test accuracy of the network: 0.535099983215332
# Test accuracy of the network: 0.8593999743461609
# Test accuracy of the network: 0.8589999675750732
# Test accuracy of the network: 0.8517999649047852
# Test accuracy of the network: 0.8608999848365784
# Test accuracy of the network: 0.8400999903678894
# Test accuracy of the network: 0.7393999695777893
# Test accuracy of the network: 0.8533999919891357
# Test accuracy of the network: 0.8486999869346619
# Test accuracy of the network: 0.5985999703407288
# Test accuracy of the network: 0.8402000069618225
# Test accuracy of the network: 0.8589999675750732
# Test accuracy of the network: 0.8285999894142151
# Test accuracy of the network: 0.8024999499320984
# Test accuracy of the network: 0.802899956703186
# Test accuracy of the network: 0.6541000008583069
# Test accuracy of the network: 0.8180999755859375
# Test accuracy of the network: 0.6807999610900879
# Test accuracy of the network: 0.8678999543190002
# Test accuracy of the network: 0.8621000051498413
# Test accuracy of the network: 0.8392999768257141
# Test accuracy of the network: 0.6825999617576599
# Test accuracy of the network: 0.715999960899353
# Test accuracy of the network: 0.764799952507019
# Test accuracy of the network: 0.863599956035614
# Test accuracy of the network: 0.8669999837875366
# Test accuracy of the network: 0.8616999983787537
# Test accuracy of the network: 0.8639000058174133
# Test accuracy of the network: 0.8569999933242798
# Test accuracy of the network: 0.8625999689102173
# Test accuracy of the network: 0.3962000012397766
# Test accuracy of the network: 0.7781999707221985
# Test accuracy of the network: 0.8680999875068665
# Test accuracy of the network: 0.7710999846458435
# Test accuracy of the network: 0.770799994468689
# Test accuracy of the network: 0.8491999506950378
# Test accuracy of the network: 0.868399977684021
# Test accuracy of the network: 0.8689000010490417
# Test accuracy of the network: 0.5756999850273132
# Test accuracy of the network: 0.8181999921798706
# Test accuracy of the network: 0.7799999713897705
# Test accuracy of the network: 0.5360000133514404
# Test accuracy of the network: 0.7738999724388123
# Test accuracy of the network: 0.847000002861023
# Test accuracy of the network: 0.8574000000953674
# Test accuracy of the network: 0.85589998960495
# Test accuracy of the network: 0.792199969291687
# Test accuracy of the network: 0.8155999779701233
# Test accuracy of the network: 0.7026000022888184
# Test accuracy of the network: 0.8592999577522278
# Test accuracy of the network: 0.8227999806404114
# Test accuracy of the network: 0.8619999885559082
# Test accuracy of the network: 0.8572999835014343
# Test accuracy of the network: 0.8317999839782715
# Test accuracy of the network: 0.43209999799728394
# Test accuracy of the network: 0.6879000067710876
# Test accuracy of the network: 0.5906000137329102
# Test accuracy of the network: 0.6814999580383301
# Test accuracy of the network: 0.8587999939918518
# Test accuracy of the network: 0.854699969291687
# Test accuracy of the network: 0.8004999756813049
# Test accuracy of the network: 0.8227999806404114
# Test accuracy of the network: 0.7655999660491943
# Test accuracy of the network: 0.6298999786376953
# Test accuracy of the network: 0.8578999638557434
# Test accuracy of the network: 0.8343999981880188
# Test accuracy of the network: 0.861799955368042
# Test accuracy of the network: 0.776199996471405
# Test accuracy of the network: 0.8596999645233154
# Test accuracy of the network: 0.854200005531311
# Test accuracy of the network: 0.8248999714851379
# Test accuracy of the network: 0.6567999720573425
# Test accuracy of the network: 0.786899983882904
# Test accuracy of the network: 0.7699999809265137
# Test accuracy of the network: 0.7511000037193298
# Test accuracy of the network: 0.8588999509811401
# Test accuracy of the network: 0.861799955368042
# Test accuracy of the network: 0.8556999564170837
# Test accuracy of the network: 0.8303999900817871
# Test accuracy of the network: 0.8287999629974365
# Test accuracy of the network: 0.8567000031471252
# Test accuracy of the network: 0.8618999719619751
# Test accuracy of the network: 0.7361999750137329
# Test accuracy of the network: 0.8563999533653259
# Test accuracy of the network: 0.865399956703186
# Test accuracy of the network: 0.8608999848365784
# Test accuracy of the network: 0.7024999856948853
# Test accuracy of the network: 0.8331999778747559
# Test accuracy of the network: 0.8312000036239624
# Test accuracy of the network: 0.8521999716758728
# Test accuracy of the network: 0.8276999592781067
# Test accuracy of the network: 0.8639000058174133
# Test accuracy of the network: 0.8689000010490417
# Test accuracy of the network: 0.8618999719619751
# Test accuracy of the network: 0.499099999666214
# Test accuracy of the network: 0.8543999791145325
# Test accuracy of the network: 0.8490999937057495
# Test accuracy of the network: 0.8113999962806702
# Test accuracy of the network: 0.8679999709129333
# Test accuracy of the network: 0.8600999712944031
# Test accuracy of the network: 0.8565999865531921
# Test accuracy of the network: 0.8299999833106995
# Test accuracy of the network: 0.7928999662399292
# Test accuracy of the network: 0.6747999787330627
# Test accuracy of the network: 0.8308999538421631
# Test accuracy of the network: 0.8495999574661255
# Test accuracy of the network: 0.8453999757766724
# Test accuracy of the network: 0.8521999716758728
# Test accuracy of the network: 0.8136999607086182
# Test accuracy of the network: 0.8180999755859375
# Test accuracy of the network: 0.7755999565124512
# Test accuracy of the network: 0.8529999852180481
# Test accuracy of the network: 0.7874999642372131
# Test accuracy of the network: 0.8495999574661255
# Test accuracy of the network: 0.8562999963760376
# Test accuracy of the network: 0.8519999980926514
# Test accuracy of the network: 0.8154000043869019
# Test accuracy of the network: 0.8464999794960022
# Test accuracy of the network: 0.8111000061035156
# Test accuracy of the network: 0.7340999841690063
# Test accuracy of the network: 0.6861000061035156
# Test accuracy of the network: 0.8583999872207642
# Test accuracy of the network: 0.8520999550819397
# Test accuracy of the network: 0.8438000082969666
# Test accuracy of the network: 0.8590999841690063
# Test accuracy of the network: 0.8664999604225159
# Test accuracy of the network: 0.8438000082969666
# Test accuracy of the network: 0.8623999953269958
# Test accuracy of the network: 0.7935999631881714
# Test accuracy of the network: 0.7687999606132507
# Test accuracy of the network: 0.847000002861023
# Test accuracy of the network: 0.8632999658584595
# Test accuracy of the network: 0.8679999709129333
# Test accuracy of the network: 0.8679999709129333
# Test accuracy of the network: 0.7802000045776367
# Test accuracy of the network: 0.7256999611854553
# Test accuracy of the network: 0.667199969291687
# Test accuracy of the network: 0.8511999845504761
# Test accuracy of the network: 0.8604999780654907
# Test accuracy of the network: 0.8325999975204468
# Test accuracy of the network: 0.8514999747276306
# Test accuracy of the network: 0.8637999892234802
# Test accuracy of the network: 0.7919999957084656
# Test accuracy of the network: 0.8598999977111816
# Test accuracy of the network: 0.8319999575614929
# Test accuracy of the network: 0.8086999654769897
# Test accuracy of the network: 0.8376999497413635
# Test accuracy of the network: 0.8650999665260315
# Test accuracy of the network: 0.8664999604225159
# Test accuracy of the network: 0.8660999536514282
# Test accuracy of the network: 0.5507999658584595
# Test accuracy of the network: 0.8565999865531921
# Test accuracy of the network: 0.858299970626831
# Test accuracy of the network: 0.7667999863624573
# Test accuracy of the network: 0.8693999648094177
# Test accuracy of the network: 0.861299991607666
# Test accuracy of the network: 0.8629999756813049
# Test accuracy of the network: 0.8501999974250793
# Test accuracy of the network: 0.8305000066757202
# Test accuracy of the network: 0.8544999957084656
# Test accuracy of the network: 0.7753999829292297
# Test accuracy of the network: 0.8561999797821045
# Test accuracy of the network: 0.85999995470047
# Test accuracy of the network: 0.8562999963760376
# Test accuracy of the network: 0.866599977016449
# Test accuracy of the network: 0.8567999601364136

# %% [markdown]
# # RSA

# %% [markdown]
# ## A function to compute Input RDMs & confusion matrices
# This function calculates
#
# 1.   Activations for a number num_samples of sample images from FashionMNIST for every model in the save files and for the desired layer.
# 2.   The Input RDM (=correlation Matrix) for every model
# 3.   The confusion matrices of every model (but does not as a default).

# %%
mlp_saves = f'{working_directory}/{fashionmnist_saves_mlp}/'
conv_saves = f'{working_directory}/{fashionmnist_saves_conv}/'


def calculate_activations_correlations(files, path, layer, num_samples=1000, show_progress=True, activations_dict = {}, corr_distances_dict = {}, 
                                       confusion_dict = {}, calc_confusion = False):
  
  dataloader_valid = torch.utils.data.DataLoader(FashionMNIST_valid, batch_size = num_samples, shuffle = False)
  inputs, labels  = next(iter(dataloader_valid))
  index_sorted =  np.argsort(labels.numpy())
  inputs, labels = inputs[index_sorted, :], labels[index_sorted]
  inputs_copy, labels_copy = deepcopy(inputs), deepcopy(labels)
  n = len(labels)

  def calculate_confusion(model, inputs, labels):
      
      confusion_matrix = np.zeros((10,10))
      with torch.no_grad():
          
          model.eval()
          inputs, labels = inputs.cuda(), labels.cuda()
          out = model(inputs)[0]
        
          for true_label in range(10):
              
              true_index = (labels==true_label) # in case not all labels are in the sample
                
              if(true_index.sum() != 0) :
                
                   (torch.max(out,1)[1])
                  
                   for output in torch.max(out[true_index],1)[1]:
                       for estimate in range(10):
                        
                           confusion_matrix[true_label, estimate] += (output == estimate).sum()
              else:
                
                  pass
    
      return(confusion_matrix)

  


  def activations_list(model):
    
      activations = []
      with torch.no_grad():
          model.eval()
          for i in range(n):
            
              if model_type == ConvNet:
                
                  single_input = inputs[i].cuda().view(1,1,28,28)
              else:
                
                  single_input = inputs[i].cuda()
                  
              activations.append(model(single_input)[layer].cpu().numpy().squeeze())
      return(activations)

  def input_rdm(list_of_activations):
      
      correlation = np.zeros((n,n))
      for i in range(n):
          for j in range(i, n):
            
              correlation[i,j] = correlation[j, i] = 1 - scipy.stats.pearsonr(list_of_activations[i], list_of_activations[j])[0]
      return(correlation)

  for i in range(len(files,)):
      if show_progress:
          
          print(i)
          
      inputs, labels = inputs_copy, labels_copy
      model_name = files[i]
      if path[i]==0:
        
          path_to_saves = mlp_saves
          model_type = feedforward
          inputs, labels = torch.autograd.Variable(inputs).view((-1, 28*28)).float(), torch.autograd.Variable(labels).long()
      
      else: 
        
          path_to_saves = conv_saves
          model_type = ConvNet
         
     
      model_dict = torch.load(f'{path_to_saves}{model_name}')
      layers = model_dict['layers']
      model = model_type(*layers).cuda()
      model.load_state_dict(model_dict['state_dict'])
      activations_dict[i] = activations_list(model)
      corr_distances_dict[i] = input_rdm(activations_dict[i])
      if calc_confusion:
        
          confusion_dict[i]= calculate_confusion(model, inputs, labels)
          
      
  return corr_distances_dict,  confusion_dict

# %% [markdown]
# ## Get dataframe of model accuracies & locations
#
# Here, the accuracy list from MLPs and CNNs are arranged into one dataframe, which contains there accuracies, location in their model type's folder and their model type. Then, the dataframe is ordered by accuracies. This allows obtaining a Model RDM with models sorted by accuracy.

# %%
with open (f'{working_directory}/accuracy_list_fashionmnist_mlp.pkl', 'rb') as fp:
    
    acc_list_mlp = pickle.load(fp)
    
with open (f'{working_directory}/accuracy_list_fashionmnist_cnn.pkl', 'rb') as fp:
    
    acc_list_convnet = pickle.load(fp)
   
acc_df_mlp = pd.DataFrame(acc_list_mlp, columns = ['acc', 'loc'])
acc_df_mlp['model_type'] = np.zeros(len(acc_df_mlp))
acc_df_convnet = pd.DataFrame(acc_list_convnet, columns = ['acc', 'loc'])
acc_df_convnet['model_type'] = np.ones(len(acc_df_convnet))
acc_df =  pd.concat([acc_df_mlp,acc_df_convnet], axis=0, ignore_index = True) 
acc_df['index'] = acc_df.index
acc_df = acc_df.sort_values(by = 'acc', ascending = True)

# %% [markdown]
# ## Calculate (or load) Input Rdms and confusion matrices
# Run the function if_calculate_activations_correlations to compute Input RDMs and confusion matrices on 400 samples taken from the FashionMNIST validation data for the penultimate layer. Save every returned dictionary using pickle.

# %%
calculate_activations_correlations_should_be_run = True
files = acc_df['loc']
path  = acc_df['model_type']
if calculate_activations_correlations_should_be_run:
 
    input_rdm_dict_fashionmnist, confusion_dict_fashionmnist = calculate_activations_correlations(list(files), list(path), num_samples= 400, calc_confusion = True, layer = 2)

    
    with open(f'{working_directory}/input_rdm_dict_fashionmnist.pkl', 'wb') as fp:
     
        pickle.dump(input_rdm_dict_fashionmnist, fp)
  
    with open(f'{working_directory}/confusion_dict_fashionmnist.pkl', 'wb') as fp:
    
        pickle.dump(confusion_dict_fashionmnist, fp)    

else:
  
    with open (f'{working_directory}/input_rdm_dict_fashionmnist.pkl', 'rb') as fp:
   
        input_rdm_dict_fashionmnist = pickle.load(fp)
# Out:
# 0
# 1

# %% [markdown]
# ## Function for Model RDM
# Functions do:
#
# 1.   define the rank-correlation distance between two upper triangular matrices of Input RDMs
# 2.   calculate the distance between two Input RDMs for a given distance function
# 3.   calculate the Model RDM (depends on 2 (necessery) and 1 (if rank correlation distance needed)
# 4.   visualize the Model RDM (shows every 15th axis tick)

# %%
def rank_corr_dist(triu_model_1, triu_model_2):
  return 1 - scipy.stats.spearmanr(triu_model_1.flatten(), triu_model_2.flatten())[0]

def dist_between_input_rdms(dist_fun, corr_matrix_1, corr_matrix_2):
  triu_model_1 = corr_matrix_1[np.triu_indices(corr_matrix_1.shape[0], k = 1)]
  triu_model_2 = corr_matrix_2[np.triu_indices(corr_matrix_2.shape[0], k = 1)]
  
  return dist_fun(triu_model_1, triu_model_2)

def calc_rdm(dist_fun, corr_distances_dict,  files=files):
  n = len(files)
  rdm = np.zeros((n,n))
  for i in range(n):
      for j in range(i, n):
          rdm[i,j] = rdm[j, i] = dist_between_input_rdms(dist_fun,
                                                            corr_distances_dict[i], 
                                                            corr_distances_dict[j])
  return rdm

def visualise_rdm(rdm, acc = acc_df['acc'] ):
  plt.figure(figsize=(14,14))
  ax = seaborn.heatmap(rdm, xticklabels = np.around(acc.astype('float') * 100), yticklabels = np.around(acc.astype('float') * 100), cmap='rainbow')
  n = 15  
  [l.set_visible(False) for (i,l) in enumerate(ax.xaxis.get_ticklabels()) if i % n != 0]
  [l.set_visible(False) for (i,l) in enumerate(ax.yaxis.get_ticklabels()) if i % n != 0]

# %% [markdown]
# ## Calculate euclidean distance Model rdm
# Calculates the Model RDM for the given dictionary (dictionary can contain Input RDMs for any layer, right now it is the penultimate layer)

# %%
rdm = calc_rdm(distance.euclidean, corr_distances_dict_fashionmnist)
visualise_rdm(rdm)
